# %% [markdown]
# <a href="https://colab.research.google.com/github/odevhesabi/Odevler/blob/main/A_02_IntroductionToMatplotlib_tr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **(1)** Create a blank figure with matplotlib functions. Plot cosine function for the numbers beetwen -3$\pi$ and 3$\pi$ with 0.1 intervals.

# %%
import matplotlib.pyplot as plt
import numpy as np



x= np.arange(-3 * np.pi, 3* np.pi, 0.1)
y=np.sin(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# **(2)** This time, create the same plot in red color with object methods.

# %%
fig, ax = plt.subplots()

x= np.arange(-3 * np.pi, 3* np.pi, 0.1)
y=np.sin(x)

ax.plot(x,y, c= "#FF914f")
plt.show()
